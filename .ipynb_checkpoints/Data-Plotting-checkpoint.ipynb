# %% [markdown]
# # ASTR19 Group Project - Tides

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize, interpolate
# %matplotlib inline

# %%
# get data
days, time, height = np.loadtxt('ASTR19_F23_group_project_data.txt', skiprows=3, unpack=True, usecols=(0, 1, 2), dtype=str)

# each element is a list [day, hour, minutes]
days_hours_and_minutes = [[days[i]] + time[i].split(':') for i in range(len(time))]

print(days_hours_and_minutes)
# Out:
# [['1', '8', '07'], ['1', '15', '37'], ['2', '8', '55'], ['2', '16', '25'], ['3', '9', '45'], ['3', '17', '14'], ['4', '10', '35'], ['4', '18', '00'], ['5', '11', '28'], ['5', '18', '46'], ['6', '12', '22'], ['6', '19', '31'], ['7', '13', '24'], ['7', '20', '16'], ['8', '3', '22'], ['8', '21', '01'], ['9', '4', '07'], ['9', '21', '46'], ['10', '4', '50'], ['10', '11', '58'], ['11', '5', '31'], ['11', '12', '56'], ['12', '6', '08'], ['12', '13', '45'], ['13', '6', '47'], ['13', '14', '25'], ['14', '7', '22'], ['14', '15', '00'], ['15', '7', '59'], ['15', '15', '34'], ['16', '8', '34'], ['16', '16', '08'], ['17', '9', '10'], ['17', '16', '41'], ['18', '9', '45'], ['18', '17', '12'], ['19', '10', '21'], ['19', '17', '45'], ['20', '10', '57'], ['20', '18', '15'], ['21', '11', '38'], ['21', '18', '48'], ['22', '12', '25'], ['22', '19', '20'], ['23', '2', '22'], ['23', '19', '52'], ['24', '2', '58'], ['24', '20', '30'], ['25', '3', '37'], ['25', '10', '44'], ['26', '4', '23'], ['26', '11', '55'], ['27', '5', '15'], ['27', '12', '57'], ['28', '6', '09'], ['28', '13', '50'], ['29', '7', '05'], ['29', '14', '39'], ['30', '7', '58'], ['30', '15', '27'], ['31', '8', '50'], ['31', '16', '10'], ['32', '9', '40'], ['32', '16', '52'], ['33', '10', '30'], ['33', '17', '34'], ['34', '11', '19'], ['34', '18', '12'], ['35', '12', '10'], ['35', '18', '49'], ['36', '1', '32'], ['36', '19', '24'], ['37', '2', '13'], ['37', '20', '00'], ['38', '2', '54'], ['38', '9', '54'], ['39', '3', '39'], ['39', '11', '15'], ['40', '4', '29'], ['40', '12', '22'], ['41', '5', '21'], ['41', '13', '14']]

# %%
# convert data points to hours
def convert_to_hours(days_hours_and_minutes):
    hours = []
    for day, hour, mins in days_hours_and_minutes:
        hour = int(hour) + int(mins) / 60
        hour += (int(day) - 1) * 24
        hours.append(hour)
    return np.array(hours)

# %%
# values for our x-axis
x = convert_to_hours(days_hours_and_minutes)
print(type(x), "hours:")
print(x)

# convert height to float
print(type(height), "height:")
y = height.astype(np.float64)
print(y)
# Out:
# <class 'numpy.ndarray'> hours:
# [  8.11666667  15.61666667  32.91666667  40.41666667  57.75
#   65.23333333  82.58333333  90.         107.46666667 114.76666667
#  132.36666667 139.51666667 157.4        164.26666667 171.36666667
#  189.01666667 196.11666667 213.76666667 220.83333333 227.96666667
#  245.51666667 252.93333333 270.13333333 277.75       294.78333333
#  302.41666667 319.36666667 327.         343.98333333 351.56666667
#  368.56666667 376.13333333 393.16666667 400.68333333 417.75
#  425.2        442.35       449.75       466.95       474.25
#  491.63333333 498.8        516.41666667 523.33333333 530.36666667
#  547.86666667 554.96666667 572.5        579.61666667 586.73333333
#  604.38333333 611.91666667 629.25       636.95       654.15
#  661.83333333 679.08333333 686.65       703.96666667 711.45
#  728.83333333 736.16666667 753.66666667 760.86666667 778.5
#  785.56666667 803.31666667 810.2        828.16666667 834.81666667
#  841.53333333 859.4        866.21666667 884.         890.9
#  897.9        915.65       923.25       940.48333333 948.36666667
#  965.35       973.23333333]
# <class 'numpy.ndarray'> height:
# [ 6.57 -0.39  5.38 -1.74  5.26 -1.36  4.13 -1.15  3.48 -1.61  2.62  0.05
#   1.83  1.01  3.57  0.73  4.54  2.17  3.76  2.88  3.9   1.92  4.73  1.74
#   5.66  0.79  5.33 -0.04  5.23 -1.12  6.67 -0.61  4.74 -0.93  4.69 -1.29
#   4.2   0.22  3.68  0.26  2.47  0.36  2.59  0.99  4.1   1.87  3.17  1.6
#   3.71  3.1   4.04  2.49  4.07  2.18  5.93  0.7   6.89  0.21  6.72  0.22
#   6.77 -1.68  5.77 -1.32  4.35 -0.73  4.23 -0.38  2.24 -0.61  3.45 -0.46
#   4.13  1.21  3.34  2.58  3.32  3.26  5.21  2.39  4.83  2.41]

# %%
# plot x vs. y
plt.plot(x, y)
plt.xlabel('hours')
plt.ylabel('height')
plt.show()

# %%
# first attempt
def sin(x, a, b):
    frequency = (2 * np.pi) / 25
    return a * (np.sin(x * frequency + b)) + 1.5

# second attempt for smoother curve
def sin2(x, a, b):
    frequency = (2 * np.pi) / (26 * 16)
    return a * (np.sin(x * frequency + b)) + 1.5

# add both together for third attempt
def sin3(x, a1, b1, a2, b2):
    frequency1 = (2 * np.pi) / 26
    frequency2 = (2 * np.pi) / (26 * 15)
    return (a1 * (np.sin(x * frequency1 + b1)) + 1.5) + (a2 * (np.sin(x * frequency2 + b2)) + 1.5)

# try a wavelength
attempt = sin(x, 3, 400)
attempt2 = sin2(x, 3, 400)
attempt3 = sin3(x, 3, 400, 5, 400)

# plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.plot(x, y, 'b-', label='Data')
ax.plot(x, attempt2, 'r-', label='Attempt2')
ax.plot(x, attempt3, 'y-', label='Attempt3')

ax.set_xlabel('Time (hours)')
ax.set_ylabel('Height (ft)')
ax.legend()

plt.show()

# %%
# get the fit for first attempt
# params_1, params_cov_1 = optimize.curve_fit(sin, x, y, sigma=0.25)
# a_fit_1, b_fit_1 = params_1
# y_fit_1 = sin(x, a_fit_1, b_fit_1)

# get fit for second attempt
# params_2, params_cov_2 = optimize.curve_fit(sin2, x, y, sigma=0.25)
# a_fit_2, b_fit_2 = params_2
# y_fit_2 = sin2(x, a_fit_2, b_fit_2)

# get fit for third attempt
params_3, params_cov_3 = optimize.curve_fit(sin3, x, y, sigma=0.25)
a1_fit, b1_fit, a2_fit, b2_fit = params_3
y_fit_3 = sin3(x, a1_fit, b1_fit, a2_fit, b2_fit)

# plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.plot(x, y, 'b-', label='Data')
# ax.plot(x, y_fit_1, 'r-', label='Fit 1')
# ax.plot(x, y_fit_2, 'g-', label='Fit 2')
ax.set_ylabel('Wave height')
ax.set_xlabel('Time (hours)')
ax.plot(x, y_fit_3, 'y-', label='Best fit')
ax.legend()

# save the fig
plt.savefig('best-fit.pdf', bbox_inches='tight', dpi=600)

plt.show()

# %%
# residuals
residuals = []
i = 0
for real, fit in zip(y, y_fit_3):
    residuals.append(real - fit)
    i += 1

residuals = np.array(residuals, dtype='float64')
print(residuals)

width = 0.5
bins = np.arange(-6, 6, width)

plt.ylabel('frequency')
plt.xlabel('residuals')
plt.hist(residuals, bins=bins)

# save the fig
plt.savefig('residuals.pdf', bbox_inches='tight', dpi=600)

plt.show()
# Out:
# [ 4.83167991 -1.1800894   3.56539516 -2.05259022  3.1965541  -1.51019212
#   1.63896032 -1.47691722  0.43107896 -2.43473022 -1.07114099 -1.53396307
#  -2.50276723 -1.49474209  1.73099017 -2.73911441  2.35123714 -2.18537655
#   1.19171833 -1.32420252  0.97135765 -2.08213943  1.48899875 -1.82075265
#   2.20348816 -2.14927159  1.73821347 -2.29781046  1.61474141 -2.75736336
#   3.10195767 -1.78351727  1.28078556 -1.87405725  1.35978494 -2.29272837
#   0.99482202 -1.11499582  0.56869604 -1.67118852 -0.60936471 -2.32141321
#  -0.54362488 -2.51798298  2.72545318 -2.42002158  0.88219188 -3.31624605
#   0.44657885  0.84094165 -0.10312374 -0.09639596 -0.75148026 -0.61930486
#   0.68109689 -2.20366543  1.49777852 -2.70675515  1.44658002 -2.63593177
#   1.85452998 -4.46214168  1.39120846 -4.03958953  0.60778333 -3.43009026
#   1.13749073 -3.15450181 -0.28465026 -3.53998965  2.70385292 -3.61486946
#   2.89424937 -2.2031254   1.36697596  1.9729881   0.47285779  2.19826449
#   1.46024261  0.75382017  0.2392933   0.11279058]

# %%
# Calculate standard deviation
standard_deviation = np.std(residuals)
print("Standard Deviation of residuals:", standard_deviation)
print("Expected error:", 0.25)
print("Error we got:", np.mean(residuals))
# Out:
# Standard Deviation of residuals: 2.0682639700609022
# Expected error: 0.25
# Error we got: -0.30459135156022454

# %%
# add 2ft to data
residuals[26] += 2
z_score = (residuals[26] - np.mean(residuals)) / np.std(residuals)
print("Z Score:", z_score)

# replot
width = 0.5
bins = np.arange(-6, 6, width)

plt.ylabel('frequency')
plt.xlabel('residuals')
plt.hist(residuals, bins=bins)

# save the fig
plt.savefig('residuals.pdf', bbox_inches='tight', dpi=600)

plt.show()
# Out:
# Z Score: 1.910165916619373
